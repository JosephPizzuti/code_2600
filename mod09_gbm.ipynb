# %%
# packages
import os
import joblib
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import GradientBoostingRegressor as GBR
from sklearn.model_selection import GridSearchCV

# set seed
seed = 5151

# %% [markdown]
# ### You'll need the California housing data (CAhousing.csv) to complete this exercise. Your goal is to predict the median house value.

# %%
CAhousing = pd.read_csv('data/CAhousing.csv')
CAhousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -120.45     34.66                 7.0       3329.0           504.0
# 1    -114.64     34.83                10.0       2502.0           573.0
# 2    -117.24     32.74                43.0       2216.0           375.0
# 3    -122.43     37.76                52.0       3771.0          1017.0
# 4    -118.02     34.13                34.0       1966.0           319.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0      1462.0       452.0         4.7875            198300.0      NEAR OCEAN
# 1      1152.0       481.0         1.7062             86800.0          INLAND
# 2       918.0       388.0         5.5289            297700.0      NEAR OCEAN
# 3      1575.0       921.0         3.5655            427300.0        NEAR BAY
# 4       980.0       297.0         7.7307            429000.0          INLAND

# %%
CAhousing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
CAhousing.shape
# Out:
# (15480, 10)

# %% [markdown]
# ### There is a single categorical variable in this dataset that we will convert to a series of binary variables.

# %%
CAhousing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6857
# INLAND        4933
# NEAR OCEAN    1974
# NEAR BAY      1712
# ISLAND           4
# Name: count, dtype: int64

# %%
# create binary variables for levels which have enough records, using '<1H OCEAN' as base.
CAhousing['ocean_prox_inland'] = (CAhousing.ocean_proximity == 'INLAND').astype(int)
CAhousing['ocean_prox_nearocean'] = (CAhousing.ocean_proximity == 'NEAR OCEAN').astype(int)
CAhousing['ocean_prox_nearbay'] = (CAhousing.ocean_proximity == 'NEAR BAY').astype(int)

# check for intended outcome
print(CAhousing['ocean_prox_inland'].value_counts())
print(CAhousing['ocean_prox_nearocean'].value_counts())
print(CAhousing['ocean_prox_nearbay'].value_counts())
# Out:
# ocean_prox_inland
# 0    10547
# 1     4933
# Name: count, dtype: int64
# ocean_prox_nearocean
# 0    13506
# 1     1974
# Name: count, dtype: int64
# ocean_prox_nearbay
# 0    13768
# 1     1712
# Name: count, dtype: int64

# %%
indep_vars = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 
              'total_bedrooms', 'population', 'households', 'median_income', 
              'ocean_prox_inland', 'ocean_prox_nearocean', 'ocean_prox_nearbay']

X = CAhousing[indep_vars]
y = CAhousing['median_house_value']

# %%
X_train, X_test, y_train, y_test, Train, Test = train_test_split(X, y, CAhousing, 
                                                                 random_state = seed, 
                                                                 test_size = 0.33, 
                                                                 shuffle = True)

# %%
X_train.corr().style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_c7bae_row0_col0, #T_c7bae_row1_col1, #T_c7bae_row2_col2, #T_c7bae_row3_col3, #T_c7bae_row4_col4, #T_c7bae_row5_col5, #T_c7bae_row6_col6, #T_c7bae_row7_col7, #T_c7bae_row8_col8, #T_c7bae_row9_col9, #T_c7bae_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c7bae_row0_col1, #T_c7bae_row1_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c7bae_row0_col2, #T_c7bae_row2_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c7bae_row0_col3, #T_c7bae_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c7bae_row0_col4, #T_c7bae_row4_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_c7bae_row0_col5, #T_c7bae_row5_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_c7bae_row0_col6, #T_c7bae_row6_col0, #T_c7bae_row7_col10, #T_c7bae_row10_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c7bae_row0_col7, #T_c7bae_row3_col9, #T_c7bae_row7_col0, #T_c7bae_row9_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_c7bae_row0_col8, #T_c7bae_row1_col4, #T_c7bae_row4_col1, #T_c7bae_row5_col10, #T_c7bae_row8_col0, #T_c7bae_row10_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_c7bae_row0_col9, #T_c7bae_row9_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c7bae_row0_col10, #T_c7bae_row10_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_c7bae_row1_col2, #T_c7bae_row2_col1, #T_c7bae_row2_col9, #T_c7bae_row3_col8, #T_c7bae_row8_col3, #T_c7bae_row9_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_c7bae_row1_col3, #T_c7bae_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_c7bae_row1_col5, #T_c7bae_row5_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_c7bae_row1_col6, #T_c7bae_row6_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_c7bae_row1_col7, #T_c7bae_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_c7bae_row1_col8, #T_c7bae_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_c7bae_row1_col9, #T_c7bae_row9_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_c7bae_row1_col10, #T_c7bae_row10_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_c7bae_row2_col3, #T_c7bae_row3_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_c7bae_row2_col4, #T_c7bae_row4_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_c7bae_row2_col5, #T_c7bae_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c7bae_row2_col6, #T_c7bae_row6_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_c7bae_row2_col7, #T_c7bae_row7_col2, #T_c7bae_row9_col10, #T_c7bae_row10_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c7bae_row2_col8, #T_c7bae_row7_col8, #T_c7bae_row8_col2, #T_c7bae_row8_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_c7bae_row2_col10, #T_c7bae_row10_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c7bae_row3_col4, #T_c7bae_row4_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_c7bae_row3_col5, #T_c7bae_row5_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_c7bae_row3_col6, #T_c7bae_row6_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_c7bae_row3_col7, #T_c7bae_row7_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_c7bae_row3_col10, #T_c7bae_row5_col8, #T_c7bae_row8_col5, #T_c7bae_row10_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_c7bae_row4_col5, #T_c7bae_row5_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_c7bae_row4_col6, #T_c7bae_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_c7bae_row4_col7, #T_c7bae_row4_col8, #T_c7bae_row5_col9, #T_c7bae_row7_col4, #T_c7bae_row8_col4, #T_c7bae_row9_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_c7bae_row4_col9, #T_c7bae_row5_col7, #T_c7bae_row6_col9, #T_c7bae_row7_col5, #T_c7bae_row9_col4, #T_c7bae_row9_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c7bae_row4_col10, #T_c7bae_row6_col10, #T_c7bae_row10_col4, #T_c7bae_row10_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_c7bae_row5_col6, #T_c7bae_row6_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_c7bae_row6_col7, #T_c7bae_row7_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_c7bae_row6_col8, #T_c7bae_row8_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c7bae_row7_col9, #T_c7bae_row9_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_c7bae_row8_col9, #T_c7bae_row9_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_c7bae_row8_col10, #T_c7bae_row10_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# </style>
# <table id="T_c7bae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7bae_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_c7bae_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_c7bae_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_c7bae_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_c7bae_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_c7bae_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_c7bae_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_c7bae_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_c7bae_level0_col8" class="col_heading level0 col8" >ocean_prox_inland</th>
#       <th id="T_c7bae_level0_col9" class="col_heading level0 col9" >ocean_prox_nearocean</th>
#       <th id="T_c7bae_level0_col10" class="col_heading level0 col10" >ocean_prox_nearbay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7bae_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_c7bae_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c7bae_row0_col1" class="data row0 col1" >-0.924779</td>
#       <td id="T_c7bae_row0_col2" class="data row0 col2" >-0.118552</td>
#       <td id="T_c7bae_row0_col3" class="data row0 col3" >0.044445</td>
#       <td id="T_c7bae_row0_col4" class="data row0 col4" >0.067878</td>
#       <td id="T_c7bae_row0_col5" class="data row0 col5" >0.095517</td>
#       <td id="T_c7bae_row0_col6" class="data row0 col6" >0.056249</td>
#       <td id="T_c7bae_row0_col7" class="data row0 col7" >-0.001915</td>
#       <td id="T_c7bae_row0_col8" class="data row0 col8" >-0.068406</td>
#       <td id="T_c7bae_row0_col9" class="data row0 col9" >0.047632</td>
#       <td id="T_c7bae_row0_col10" class="data row0 col10" >-0.471177</td>
#     </tr>
#     <tr>
#       <th id="T_c7bae_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_c7bae_row1_col0" class="data row1 col0" >-0.924779</td>
#       <td id="T_c7bae_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c7bae_row1_col2" class="data row1 col2" >0.017276</td>
#       <td id="T_c7bae_row1_col3" class="data row1 col3" >-0.034301</td>
#       <td id="T_c7bae_row1_col4" class="data row1 col4" >-0.064393</td>
#       <td id="T_c7bae_row1_col5" class="data row1 col5" >-0.104774</td>
#       <td id="T_c7bae_row1_col6" class="data row1 col6" >-0.070660</td>
#       <td id="T_c7bae_row1_col7" class="data row1 col7" >-0.091395</td>
#       <td id="T_c7bae_row1_col8" class="data row1 col8" >0.362431</td>
#       <td id="T_c7bae_row1_col9" class="data row1 col9" >-0.162865</td>
#       <td id="T_c7bae_row1_col10" class="data row1 col10" >0.352288</td>
#     </tr>
#     <tr>
#       <th id="T_c7bae_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_c7bae_row2_col0" class="data row2 col0" >-0.118552</td>
#       <td id="T_c7bae_row2_col1" class="data row2 col1" >0.017276</td>
#       <td id="T_c7bae_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c7bae_row2_col3" class="data row2 col3" >-0.356225</td>
#       <td id="T_c7bae_row2_col4" class="data row2 col4" >-0.312179</td>
#       <td id="T_c7bae_row2_col5" class="data row2 col5" >-0.296755</td>
#       <td id="T_c7bae_row2_col6" c

# %%
Train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  10371.000000  10371.000000        10371.000000  10371.000000
# mean    -119.576317     35.648347           28.707646   2631.445569
# std        1.997211      2.140070           12.631120   2173.616930
# min     -124.260000     32.560000            1.000000      8.000000
# 25%     -121.770000     33.940000           18.000000   1454.000000
# 50%     -118.510000     34.260000           29.000000   2126.000000
# 75%     -118.020000     37.730000           37.000000   3127.000000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    10257.000000  10371.000000  10371.000000   10371.000000
# mean       537.541484   1426.518851    500.422524       3.868065
# std        425.582759   1137.463225    388.555637       1.885826
# min          1.000000      5.000000      1.000000       0.499900
# 25%        296.000000    791.000000    282.000000       2.556800
# 50%        435.000000   1163.000000    410.000000       3.534500
# 75%        640.000000   1719.000000    601.000000       4.747400
# max       6445.000000  28566.000000   6082.000000      15.000100
#
#        median_house_value  ocean_prox_inland  ocean_prox_nearocean  \
# count        10371.000000       10371.000000          10371.000000
# mean        206399.612284           0.323787              0.124771
# std         115215.425942           0.467943              0.330475
# min          14999.000000           0.000000              0.000000
# 25%         118750.000000           0.000000              0.000000
# 50%         179800.000000           0.000000              0.000000
# 75%         264000.000000           1.000000              0.000000
# max         500001.000000           1.000000              1.000000
#
#        ocean_prox_nearbay
# count        10371.000000
# mean             0.109247
# std              0.311964
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %% [markdown]
# ### We see that `total_bedrooms` has a few missing values, and it is also very correlated with `total_rooms`. Because of this, it's easiest to remove it from our training set.

# %%
indep_vars.remove("total_bedrooms")

# %% [markdown]
# ### We'll define some helper functions here:
# (1) to calculate MSE, and
# (2) to display the improvement of a GBM on test data as additional trees are constructed.

# %%
def mse(y, y_hat):
    """
    Calculate the MSE of a model given actual and predicted values
    """
    # calculate the residual error for each individual record
    resid = y - y_hat
    # square the residual (hence "squared error")
    sq_resid = resid**2
    # calculate the sum of squared errors
    SSR = sum(sq_resid)
    # divide by the number of records to get the mean squared error
    MSE = SSR / y.shape[0]
    return MSE

def gbm_progress(model_name, X_test, y_test):
    """
    Plot the 'progress' of a GBM on a test set to assess robustness
    """
    test_error = np.zeros_like(model_name.train_score_)
    for idx, y_ in enumerate(model_name.staged_predict(X_test)):
        test_error[idx] = np.mean((y_test - y_)**2)

    plot_idx = np.arange(model_name.train_score_.shape[0])
    ax = subplots(figsize=(8,8))[1]
    ax.plot(plot_idx,
            model_name.train_score_,
            'b',
            label='Training')
    ax.plot(plot_idx,
            test_error,
            'r',
            label='Test')
    ax.legend();

# %% [markdown]
# ### Build a basic GBM first.

# %%
# Documentation: https://scikit-learn.org/dev/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html

gbm_basic = GBR(learning_rate=0.1,
               n_estimators=250,
               max_depth=10,
               min_samples_split=2,
               subsample=1,
               random_state=seed)

gbm_basic.fit(X_train[indep_vars], y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, n_estimators=250, random_state=5151,
#                           subsample=1)

# %%
y_hat_basic = gbm_basic.predict(X_test[indep_vars])

mse_basic = mse(y_test, y_hat_basic)
print('test mse: ',mse_basic)
# Out:
# test mse:  2522992630.270553

# %% [markdown]
# ### When we plot the performance of the model on training and test data, we see that performance no longer improves after a certain number of trees (in this case, between 50-100 trees).

# %%
gbm_progress(gbm_basic, X_test[indep_vars], y_test)

# %% [markdown]
# ### Now you'll have the chance to choose optimal hyperparameters to build a better GBM.
# Once the candidate hyperparameters are chosen, use 5-fold cross-validation to decide which collection of hyperparameters are best.

# %%
def get_best_gbm(X, y, results_path="gridsearch_results.pkl", force_retrain=False):
    """
    Runs GridSearchCV OR loads precomputed results if available.

    Parameters:
        X, y : training data
        results_path : where results are saved
        force_retrain : if True, ignore saved file and rerun

    Returns:
        best_model : fitted model
        best_params : dict
    """

    # Fast Version: load existing results
    if os.path.exists(results_path) and not force_retrain:
        data = joblib.load(results_path)
        print("Loaded precomputed GridSearchCV results.")
        return data["best_model"], data["best_params"]

    # Slow Version: run grid search via cross-validation
    print("Running GridSearchCV...")

    ## Define model
    gbm_cv = GBR(random_state=seed)

    ## Define hyperparameter grid. Choose between 1 and 4 values to test for each one.
    #fillin
    param_grid = {
        "n_estimators": [100,500,1000],
        "learning_rate": [0.05,.01,.005],
        "max_depth": [3,5,8],
        "min_samples_leaf": [10,20,50],
        "subsample": [1,0.75,0.5]
    }

    grid_search = GridSearchCV(
        estimator=gbm_cv,
        param_grid=param_grid,
        cv=5,                               # number of folds
        scoring="neg_mean_squared_error",   # how we evaluate which model is best
        n_jobs=-1,                          # use all available cores
        verbose=3
    )

    grid_search.fit(X, y)

    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    ## Save results. Gradescope will use this file instead of rerunning the grid search.
    joblib.dump({
        "best_model": best_model,
        "best_params": best_params,
        "cv_results": grid_search.cv_results_
    }, results_path)

    print(f"Saved results to {results_path}")

    return best_model, best_params

# %%
# Identify best model
best_model, best_params = get_best_gbm(X_train[indep_vars], y_train, force_retrain=False)

print("Best parameters:")
print(best_params)
# Out:
# Running GridSearchCV...
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-3644709808.086 total time=   0.8s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-3767344524.031 total time=   0.6s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2748153491.558 total time=   4.0s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2622711174.530 total time=   2.8s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2550594226.135 total time=   8.1s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-3833271864.854 total time=   1.0s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-3775379777.024 total time=   0.8s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-3734945362.932 total time=   0.6s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2535244065.042 total time=   5.2s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2589136155.854 total time=   3.0s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2425767564.719 total time=   8.4s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2459642129.877 total time=   6.0s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2548302367.089 total time=   4.3s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2426518788.187 total time=  10.9s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-3050924804.598 total time=   1.8s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-3009467548.354 total time=   1.4s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-2987173790.326 total time=   1.0s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2455015693.342 total time=   8.9s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2353909533.370 total time=   5.2s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2195990654.376 total time=  14.4s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-2917008051.853 total time=   1.9s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-2850386750.288 total time=   1.4s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-2871002553.748 total time=   1.0s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2367292379.223 total time=   9.0s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2375784469.488 total time=   5.3s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2227816817.907 total time=  14.4s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2291299720.755 total time=   9.8s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2351594803.067 total time=   7.0s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2300310794.177 total time=  18.1s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-2398154734.786 total time=   2.7s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-2437418053.884 total time=   2.1s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-2461164277.368 total time=   1.4s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2249425944.225 total time=  14.2s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2229758350.471 total time=  29.1s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-2530984127.378 total time=   2.8s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-2501735963.671 total time=   2.2s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-2490504876.109 total time=   1.5s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2382671339.453 total time=  14.3s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2406527429.324 total time=   7.5s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2365077741.828 total time=  22.0s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2426288955.320 total time=  14.9s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2359874402.877 total time=  10.8s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2364451219.525 total time=  29.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-6118724073.263 total time=   1.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-6110587829.064 total time=   1.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-6097582608.562 total time=   0.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-3568014068.341 total time=   5.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-3535408709.497 total time=   4.7s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-3770406873.374 total time=   3.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-3098666454.072 total time=   9.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-6820178438.548 total time=   1.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-6792171766.474 total time=   0.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-6778380087.334 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-3879954004.427 total time=   5.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-3790511305.175 total time=   3.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2929407502.287 total time=   8.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2905764493.373 total time=   6.5s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-3547248816.101 total time=   4.5s[CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-3789114269.845 total time=   0.8s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-3641983908.601 total time=   0.6s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2646635817.801 total time=   4.0s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2810904140.094 total time=   2.8s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2400242246.977 total time=   8.2s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-3763571361.593 total time=   1.0s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-3607007610.964 total time=   0.8s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-3750052531.755 total time=   0.6s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2742500378.044 total time=   5.2s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2713369993.446 total time=   3.0s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2494653245.496 total time=   8.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2520753031.892 total time=   6.1s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2620032347.683 total time=   4.3s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2373446081.951 total time=  10.8s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-2889216218.539 total time=   1.8s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-2849739146.020 total time=   1.4s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-2916992072.001 total time=   1.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2244849343.268 total time=   9.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2152266024.048 total time=  18.5s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2134866646.058 total time=  10.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2231400253.756 total time=   7.3s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2170780644.145 total time=  18.5s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-2948538452.463 total time=   1.8s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-2964505840.505 total time=   1.4s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-2989581668.072 total time=   1.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-2281110875.404 total time=   9.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-2338500418.320 total time=   4.8s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2188907016.076 total time=  14.2s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2227693509.177 total time=   9.6s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2177161345.016 total time=  10.9s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2153402537.517 total time=   7.4s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2316819784.038 total time=  22.4s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-2566271344.121 total time=   2.8s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-2604833260.679 total time=   2.2s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-2654390241.057 total time=   1.5s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2407445774.801 total time=  14.4s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2351864644.408 total time=   7.6s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2358520481.441 total time=  21.8s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2326596252.361 total time=  14.9s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2443070320.836 total time=  10.8s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2415796854.032 total time=  28.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-6739481159.363 total time=   1.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-6726723630.339 total time=   1.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-6717829286.132 total time=   0.8s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-4023913700.484 total time=   5.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-3952254826.715 total time=   4.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-3479138260.042 total time=   3.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2943889152.348 total time=   9.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-6120632879.791 total time=   1.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-6110929278.551 total time=   0.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-6099872340.299 total time=   0.6s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-3575558406.375 total time=   5.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-3477401602.496 total time=   3.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-3104926682.115 total time=   9.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-3050839216.323 total time=   6.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-3872985177.338 total time=   4.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-3138132116.128 total time=  11.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-5907527815.212 total time=   1.8s[CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-3476703053.510 total time=   0.8s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-3990922717.637 total time=   0.6s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2830859173.643 total time=   4.0s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2607558834.504 total time=   2.8s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2371519899.184 total time=   8.2s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-3799850865.161 total time=   1.0s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-3681077807.597 total time=   0.8s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-3633124184.481 total time=   0.6s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2654802116.422 total time=   5.2s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2801603116.358 total time=   3.0s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2395666727.916 total time=   8.4s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2383971651.735 total time=   6.1s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2780637367.569 total time=   4.3s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2580372841.467 total time=  10.9s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-2964572581.015 total time=   1.9s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-2915373337.964 total time=   1.4s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-3007301120.659 total time=   1.0s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2383052010.646 total time=   9.0s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2302808334.770 total time=  18.6s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2357248718.773 total time=  10.0s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2313605252.671 total time=   7.3s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2277614104.799 total time=  18.4s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-3018611746.086 total time=   1.8s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-3000635989.493 total time=   1.4s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-3102151059.221 total time=   1.0s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-2479773380.910 total time=   8.9s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-2389146044.819 total time=   4.8s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2279784148.638 total time=  14.2s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2318108882.520 total time=   9.6s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2198289220.235 total time=  11.0s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2261410978.805 total time=   7.5s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2185818004.806 total time=  22.5s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-2422367281.347 total time=   2.8s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-2460808712.162 total time=   2.3s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-2412117937.002 total time=   1.5s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2240381311.347 total time=  14.3s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2198110510.657 total time=   7.5s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2173197650.031 total time=  21.9s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2196778946.988 total time=  15.0s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2252836208.300 total time=  10.9s
# [CV 5/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2238889439.721 total time=  28.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-6380843982.877 total time=   1.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-6364731044.418 total time=   1.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-6348876614.988 total time=   0.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-3756734200.565 total time=   5.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-3674243073.983 total time=   4.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-3056888695.960 total time=  11.4s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-3051073418.472 total time=   6.4s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-3659838054.845 total time=   4.5s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-3052490871.869 total time=  11.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-6379516506.567 total time=   1.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-6359608124.266 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-6348016965.847 total time=   0.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-3732725573.825 total time=   5.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-3646049550.101 total time=   3.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2994270080.973 total time=   9.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-3010290451.741 total time=   6.4s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2869864779.006 total time=   7.1s[CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-3770449004.296 total time=   0.8s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-3490070839.649 total time=   0.6s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2550496864.170 total time=   3.9s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2885403024.605 total time=   2.8s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2650055003.822 total time=   8.1s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-3981639375.561 total time=   1.0s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-3940119879.801 total time=   0.8s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-3980845426.397 total time=   0.6s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2805248011.671 total time=   5.1s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2878565468.042 total time=   3.0s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2647241019.794 total time=   8.4s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2690219297.244 total time=   6.0s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2862433890.386 total time=   4.3s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2634700539.992 total time=  10.9s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2517059508.588 total time=   6.1s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2222440236.843 total time=   7.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2248134109.030 total time=   5.1s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2090570569.418 total time=  14.4s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-2869355351.137 total time=   1.9s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-2855981128.315 total time=   1.4s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-2873508095.668 total time=   1.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2262622724.336 total time=   9.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2248027931.779 total time=   5.3s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2124948169.357 total time=  14.4s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2109362857.999 total time=   9.8s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2281652255.464 total time=   7.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2204185238.119 total time=  18.1s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-2417841797.400 total time=   2.7s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-2433334370.499 total time=   2.1s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-2457810080.052 total time=   1.5s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2166361891.484 total time=  14.1s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2152869476.091 total time=  29.1s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2152034123.397 total time=  15.4s
# [CV 3/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2153825737.438 total time=  10.9s
# [CV 4/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2336562126.515 total time=  28.7s
# [CV 4/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-2683019025.240 total time=   2.6s
# [CV 4/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-2681014125.893 total time=   2.1s
# [CV 4/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-2759820692.971 total time=   1.3s
# [CV 4/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-2408982509.908 total time=  14.1s
# [CV 4/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-2408164735.507 total time=   7.2s
# [CV 4/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2328567140.448 total time=  22.0s
# [CV 4/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2378638215.301 total time=  14.4s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-3128928038.974 total time=  11.4s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-3088732606.641 total time=   6.4s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-3858483255.789 total time=   4.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-3144588182.955 total time=  11.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-6822576292.470 total time=   1.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-6794340887.450 total time=   0.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-6781975458.897 total time=   0.7s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-3892315928.328 total time=   5.7s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-3832426691.120 total time=   3.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-3095633968.405 total time=   9.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-3095871071.844 total time=   6.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2848605725.309 total time=   7.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2839349768.275 total time=   5.0s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2444954751.650 total time=  14.3s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-5925138462.843 total time=   1.8s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-5885315762.235 total time=   1.4s[CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-3575354890.321 total time=   1.0s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2694338984.664 total time=   5.0s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2402964569.358 total time=  10.1s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2397023140.357 total time=   5.8s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2566774779.434 total time=   4.2s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2387922794.665 total time=  10.5s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-3552715384.192 total time=   1.1s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-3451112256.285 total time=   0.9s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-3516489789.293 total time=   0.6s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-2540392412.031 total time=   5.4s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-2551709429.995 total time=   3.0s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2431698241.623 total time=   8.6s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2440079531.409 total time=   6.2s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2335074309.866 total time=   7.0s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2368484992.916 total time=   5.1s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2278232286.724 total time=  14.4s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-2793902391.921 total time=   1.9s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-2792525656.765 total time=   1.4s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-2833662500.915 total time=   1.0s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2345136623.671 total time=   9.1s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2353366404.697 total time=   5.3s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2294369352.367 total time=  14.3s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2322113847.637 total time=   9.8s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2356371074.558 total time=   7.0s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2347251821.254 total time=  18.0s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-2538119499.719 total time=   2.7s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-2570590701.350 total time=   2.1s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-2631283547.194 total time=   1.4s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2383578744.699 total time=  14.2s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2408398169.278 total time=  29.2s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2336481646.176 total time=  15.3s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2367446599.711 total time=  10.9s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2385643695.196 total time=  28.5s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-2726133981.150 total time=   2.6s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-2734254864.575 total time=   2.0s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-2853953798.665 total time=   1.4s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-2432316153.111 total time=  14.0s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-2491574179.128 total time=   7.3s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2415567629.277 total time=  21.9s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2454444423.328 total time=  14.4s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-3918337785.233 total time=   3.3s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-3311139352.298 total time=   9.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-6741417150.388 total time=   1.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-6733178664.518 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-6724677006.299 total time=   0.6s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-4023545151.878 total time=   5.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-3929122587.254 total time=   3.3s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-3300074426.425 total time=   9.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-3285593482.891 total time=   6.5s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-3992705237.091 total time=   4.5s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-3335559668.832 total time=  11.3s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-5831500911.605 total time=   1.8s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-5802998157.029 total time=   1.4s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-5797689026.108 total time=   1.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-3037047931.330 total time=   9.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2890257521.495 total time=   5.0s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2532277267.336 total time=  14.3s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-5648203720.855 total time=   1.8s[CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-3970739694.797 total time=   0.8s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-3788603161.460 total time=   0.6s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2597319768.617 total time=   4.0s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2704578446.686 total time=   2.8s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2481045584.280 total time=   8.1s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-3542030883.680 total time=   1.0s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-3501563412.655 total time=   0.8s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-3494639705.563 total time=   0.6s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2566571361.830 total time=   5.2s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2603052132.525 total time=   3.0s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2597850751.649 total time=   8.4s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2623970006.548 total time=   6.0s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2588888101.053 total time=   4.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2465593043.427 total time=  10.9s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-2916592519.474 total time=   1.9s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-2832896663.977 total time=   1.4s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-2873886034.629 total time=   1.0s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2374472692.212 total time=   9.0s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2290873768.966 total time=  18.6s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-3065006078.253 total time=   1.9s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-3089777035.930 total time=   1.4s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-3092472165.286 total time=   1.0s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2466077824.441 total time=   9.1s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2500888309.247 total time=   5.3s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2433083182.771 total time=  14.4s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2396761300.339 total time=   9.8s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2523944728.699 total time=   7.0s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2454879030.122 total time=  18.2s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-2535034719.944 total time=   2.8s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-2505188245.283 total time=   2.1s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-2472027317.222 total time=   1.4s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2358755725.062 total time=  14.2s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2352450724.498 total time=  29.0s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2418274417.819 total time=  15.4s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2361303979.933 total time=  10.8s
# [CV 1/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2416882835.751 total time=  28.7s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-2544806781.189 total time=   2.6s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-2586784370.552 total time=   2.1s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-2634273345.506 total time=   1.3s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-2386812117.585 total time=  13.9s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-2379009978.168 total time=   7.3s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2339112741.244 total time=  22.1s
# [CV 2/5] END learning_rate=0.05, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2371590317.348 total time=  14.4s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-3791644934.844 total time=   3.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-3211961985.589 total time=   9.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-6386414982.203 total time=   1.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-6373561339.101 total time=   0.9s
# ...
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2328872519.822 total time=  21.8s
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-4762828815.014 total time=   2.7s
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-4772998947.157 total time=   2.1s
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-4816305826.117 total time=   1.4s
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-2568630225.893 total time=  13.8s
# [CV 5/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-2422793568.111 total time=   7.2s
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2386737047.919 total time=  21.4s
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2390757138.871 total time=  14.6s
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-2681493153.780 total time=  10.0s
# [CV 4/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2510661130.915 total time=  27.0s
# [CV 4/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-8377094350.249 total time=   1.2s
# [CV 4/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-8369602433.961 total time=   1.0s
# [CV 4/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-8346781951.066 total time=   0.7s
# [CV 4/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-4713120259.201 total time=   5.9s
# [CV 4/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-4670422627.560 total time=   4.6s
# [CV 4/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-3859131275.543 total time=  11.6s
# [CV 4/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-3796599435.227 total time=   6.5s
# [CV 3/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-4916105057.346 total time=   4.7s
# [CV 3/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-3870793692.233 total time=  11.5s
# [CV 3/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-8821158373.588 total time=   1.2s
# [CV 3/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-8809784165.802 total time=   0.9s
# [CV 3/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-8801328687.806 total time=   0.7s
# [CV 3/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-4952412794.998 total time=   6.1s
# [CV 3/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-4887892137.862 total time=   3.4s
# [CV 3/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-3868108592.198 total time=   9.8s
# [CV 4/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-3805490433.670 total time=   6.8s
# [CV 5/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-3680474940.065 total time=   7.5s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2817398481.064 total time=  19.4s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2771446242.327 total time=  10.5s
# [CV 1/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-3886289954.815 total time=   7.5s
# [CV 1/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-3101347691.740 total time=  19.1s
# [CV 1/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-8147987904.612 total time=   1.9s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-7499007742.645 total time=   1.5s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-7503306423.958 total time=   1.0s
# [CV 1/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-3979527998.218 total time=   9.6s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-3594608064.221 total time=   5.2s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2824572725.172 total time=  14.9s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2849939317.967 total time=  10.3s
# [CV 2/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=0.75;, score=-2808942088.324 total time=  11.0s
# [CV 2/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-2795562413.411 total time=   7.7s
# [CV 2/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2461102329.913 total time=  22.3s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2487575288.677 total time=  15.1s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2977373195.954 total time=  11.0s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2574238437.764 total time=  28.4s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-7341419883.329 total time=   2.6s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-7377429065.516 total time=   2.0s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-7449212500.344 total time=   1.3s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-3201887020.432 total time=  13.5s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-3266447936.520 total time=   6.9s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2669442078.540 total time=  21.3s
# [CV 4/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2724175225.754 total time=  12.8s
#
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-3043165190.838 total time=   5.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2685972623.565 total time=  14.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2695144796.615 total time=   9.8s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-3116208264.164 total time=   7.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2773303169.975 total time=  18.1s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-4854346607.630 total time=   2.7s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-4805968082.118 total time=   2.1s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-4838598651.079 total time=   1.4s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2522541500.274 total time=  13.9s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2410655645.597 total time=  28.3s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2416372881.033 total time=  14.9s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2574885285.141 total time=  10.5s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2416979936.217 total time=  27.9s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-5170872541.240 total time=   2.5s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-5204884297.210 total time=   2.0s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-5359658306.392 total time=   1.3s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-2713119070.906 total time=  13.1s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-2789373896.999 total time=   6.7s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2517012657.496 total time=  20.5s
# [CV 1/5] END learning_rate=0.01, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2573728376.783 total time=  14.0s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-4873145830.659 total time=   3.3s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-3950589533.925 total time=   9.2s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-8759392521.521 total time=   1.2s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-8755024232.729 total time=   0.9s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-8744947569.095 total time=   0.7s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-4946645132.747 total time=   5.8s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-4882970469.352 total time=   3.4s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-3959507630.350 total time=   9.2s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-3904985359.940 total time=   6.7s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-4921481764.723 total time=   4.8s
# [CV 1/5] END learning_rate=0.005, max_depth=3, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-4057520972.271 total time=  12.1s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-7489793894.334 total time=   1.9s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-7456410107.787 total time=   1.5s
# [CV 2/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-7438002218.869 total time=   1.1s
# [CV 1/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-3911315588.513 total time=   9.6s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=500, subsample=0.5;, score=-3776106416.583 total time=   5.3s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=10, n_estimators=1000, subsample=0.75;, score=-2864272977.464 total time=  15.1s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=1;, score=-8225875350.009 total time=   1.9s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.75;, score=-8181956868.373 total time=   1.5s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=100, subsample=0.5;, score=-8159118616.909 total time=   1.1s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=1;, score=-3918075478.694 total time=   9.8s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=500, subsample=0.5;, score=-3803815014.838 total time=   5.2s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.75;, score=-2877694364.074 total time=  14.9s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=20, n_estimators=1000, subsample=0.5;, score=-2856466453.515 total time=  10.5s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=500, subsample=0.75;, score=-3911553814.410 total time=   7.4s
# [CV 3/5] END learning_rate=0.005, max_depth=5, min_samples_leaf=50, n_estimators=1000, subsample=1;, score=-2954500887.203 total time=  19.2s
# [CV 3/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=1;, score=-7385686079.397 total time=   2.9s
# [CV 3/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.75;, score=-7382093885.333 total time=   2.3s
# [CV 3/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=100, subsample=0.5;, score=-7413032465.490 total time=   1.5s
# [CV 3/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=500, subsample=1;, score=-2974955876.420 total time=  14.5s
# [CV 3/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=1;, score=-2422046538.516 total time=  29.1s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=10, n_estimators=1000, subsample=0.5;, score=-2410825688.982 total time=  15.2s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=20, n_estimators=500, subsample=0.75;, score=-2870067695.915 total time=  11.0s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=20, n_estimators=1000, subsample=1;, score=-2414878346.916 total time=  28.4s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=1;, score=-7200669817.528 total time=   2.6s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.75;, score=-7254189735.529 total time=   2.0s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=100, subsample=0.5;, score=-7368344384.156 total time=   1.3s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=1;, score=-3027107707.504 total time=  13.5s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=500, subsample=0.5;, score=-3150486777.305 total time=   6.8s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.75;, score=-2526213316.776 total time=  21.2s
# [CV 5/5] END learning_rate=0.005, max_depth=8, min_samples_leaf=50, n_estimators=1000, subsample=0.5;, score=-2590207618.494 total time=  12.8s

# %% [markdown]
# ### Your grade on this assignment will be partially determined by the mean squared error on a separate holdout set. You can approximate this using the test set.

# %%
# Evaluate on test set 
y_pred = best_model.predict(X_test[indep_vars])
mse_best = mse(y_test, y_pred)

print("Test MSE:", mse_best)
# Out:
# Test MSE: 2221670395.903372
